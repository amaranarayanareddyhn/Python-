# %%
print("this is my day 3 for the learning for the push the code into the github using git commands")
# Out:
# this is my day 3 for the learning for the push the code into the github using git commands
