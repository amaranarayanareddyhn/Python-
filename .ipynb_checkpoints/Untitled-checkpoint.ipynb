# %%
print("welcome to the my world !!!")
# Out:
# welcome to the my world !!!

# %%
# variables
# A variable is a name used to store data.
# example
#integers
number = 25
print(number)
#string
string1 = 'Amara'
print(string1)
#float
float1 = 9.49
print(float1)
# true or false
alive = True
print(alive)
# Out:
# 25
# Amara
# 9.49
# True
